# %%
import pandas as pd

star_wars = pd.read_csv('star_wars.csv',encoding = 'ISO-8859-1')

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
star_wars = star_wars[star_wars['RespondentID'].notnull() == True]

# %%
star_wars['RespondentID'].notnull()
# Out:
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
#         ...
# 1157    True
# 1158    True
# 1159    True
# 1160    True
# 1161    True
# 1162    True
# 1163    True
# 1164    True
# 1165    True
# 1166    True
# 1167    True
# 1168    True
# 1169    True
# 1170    True
# 1171    True
# 1172    True
# 1173    True
# 1174    True
# 1175    True
# 1176    True
# 1177    True
# 1178    True
# 1179    True
# 1180    True
# 1181    True
# 1182    True
# 1183    True
# 1184    True
# 1185    True
# 1186    True
# Name: RespondentID, Length: 1186, dtype: bool

# %%
yes_no = {"Yes": True, "No": False}

for col in [
    "Have you seen any of the 6 films in the Star Wars franchise?",
    "Do you consider yourself to be a fan of the Star Wars film franchise?"
    ]:
    star_wars[col] = star_wars[col].map(yes_no)

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
star_wars.columns[3:9]
# Out:
# Index(['Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
import numpy as np

star_wars.rename(columns={'Which of the following Star Wars films have you seen? Please select all that apply.':'seen_1',
                          'Unnamed: 4':'seen_2','Unnamed: 5':'seen_3','Unnamed: 6':'seen_4',
                          'Unnamed: 7':'seen_5','Unnamed: 8':'seen_6',},inplace=True)


yes_no2 = {
    'Star Wars: Episode I  The Phantom Menace': True,
    'Star Wars: Episode II  Attack of the Clones' : True,
    'Star Wars: Episode III  Revenge of the Sith' : True,
    'Star Wars: Episode IV  A New Hope': True,
    'Star Wars: Episode V The Empire Strikes Back' : True,
    'Star Wars: Episode VI Return of the Jedi' : True,
    np.nan:False
}

for col in ['seen_1','seen_2','seen_3','seen_4','seen_5','seen_6']:
    star_wars[col]=star_wars[col].map(yes_no2)

# %%
star_wars['seen_6'].value_counts()
# Out:
# Star Wars: Episode VI Return of the Jedi    738
# Name: seen_6, dtype: int64

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
star_wars.rename(columns={'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'Star Wars: Episode I The Phantom Menace',
                          'Unnamed: 10': 'Star Wars: Episode II Attack of the Clones',
                          'Unnamed: 11': 'Star Wars: Episode III Revenge of the Sith',
                          'Unnamed: 12': 'Star Wars: Episode IV A New Hope',
                          'Unnamed: 13': 'Star Wars: Episode V The Empire Strikes Back',
                          'Unnamed: 14': 'Star Wars: Episode VI Return of the Jedi'
},inplace=True)

# %%
star_wars[star_wars.columns[9:15]].mean()
# Out:
# Star Wars: Episode I The Phantom Menace         3.732934
# Star Wars: Episode II Attack of the Clones      4.087321
# Star Wars: Episode III Revenge of the Sith      4.341317
# Star Wars: Episode IV A New Hope                3.272727
# Star Wars: Episode V The Empire Strikes Back    2.513158
# Star Wars: Episode VI Return of the Jedi        3.047847
# dtype: float64

# %% [markdown]
# # Rankings
#
# The original trilogy as a whole is ranked higher than the second trilogy. This is consistent with the older generation as well as die hard fans.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.bar(range(6),star_wars[star_wars.columns[9:15]].mean())
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(range(6),star_wars[star_wars.columns[3:9]].sum())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# The original movies were seen by more respondents than the newer movies. This reinforces what we saw with the rankings, the older movies are more popular.

# %%
star_wars = star_wars.rename(columns={'Do you consider yourself to be a fan of the Expanded Universe?ÂÃ¦':'Do you consider yourself to be a fan of the Expanded Universe?'})

# %%
star_trek_fans = star_wars[star_wars['Do you consider yourself to be a fan of the Star Trek franchise?'] == "Yes"]
star_trek_haters = star_wars[star_wars['Do you consider yourself to be a fan of the Star Trek franchise?'] == "No"]

# %%
plt.bar(range(6),star_trek_fans[star_trek_fans.columns[9:15]].mean())
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(range(6),star_trek_haters[star_trek_haters.columns[9:15]].mean())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Star Trek fans ranking of Star Wars movies
#
# Star Trek fans apprea to be bigger fans of the Star Wars original trilogy than those who do not enjoy Star Trek. This indicates that the original trilogy could be similar to Star Trek more than the second trilogy.

# %%
plt.bar(range(6),star_trek_fans[star_trek_fans.columns[3:9]].sum())
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(range(6),star_trek_haters[star_trek_haters.columns[3:9]].sum())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Star Trek Fans viewing of Star Wars movies
#
# Those who do not like star trek have significantly not watched the new trilogy, as opposed to star trek fans who watched the new trilogy much more. This could indicate that they were excited for the new trilogy and went to watch but were disappointed
